# %%
import pandas as pd
import numpy as np
import matplotlib.pylot as plt
import seaborn as sns
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 3
#       1 import pandas as pd
#       2 import numpy as np
# ----> 3 import matplotlib.pylot as plt
#       4 import seaborn as sns
#
# ModuleNotFoundError: No module named 'matplotlib.pylot'

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("housing.csv")

# %%
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
data.dropna()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
data.dropna(inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20433 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20433 non-null  float64
#  1   latitude            20433 non-null  float64
#  2   housing_median_age  20433 non-null  float64
#  3   total_rooms         20433 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20433 non-null  float64
#  6   households          20433 non-null  float64
#  7   median_income       20433 non-null  float64
#  8   median_house_value  20433 non-null  float64
#  9   ocean_proximity     20433 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.7+ MB

# %%
from sklearn.model_selection import train_test_split

X = data.drop(['median_house_value'], axis=1)
y = data['median_house_value']

# %%
X
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 X
#
# NameError: name 'X' is not defined

# %%
from sklearn.datasets import fetch_california_housing
import pandas as pd

# Load data
raw = fetch_california_housing()
data = pd.DataFrame(raw.data, columns=raw.feature_names)

# Tambahkan kolom target
data['median_house_value'] = raw.target

# Baru deh ini jalan:
X = data.drop(['median_house_value'], axis=1)
y = data['median_house_value']

# %%
from sklearn.model_selection import train_test_split

X = data.drop(['median_house_value'], axis=1)
y = data['median_house_value']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0,2)
# Out:
#   Cell In[18], line 1
#     X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0,2)
#                                                                            ^
# SyntaxError: positional argument follows keyword argument

# %%
train_data = X_train.join(y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 train_data = X_train.join(y_train)
#
# NameError: name 'X_train' is not defined

# %%
train_data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 train_data
#
# NameError: name 'train_data' is not defined

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
train_data = X_train.join(y_train)

# %%
train_data
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 12517  2.2125      52.0  5.124294   1.016949       479.0  2.706215     38.56
# 4761   3.0856      49.0  3.717172   0.895623       668.0  2.249158     34.04
# 12901  2.2574      19.0  4.667506   1.045340       772.0  1.944584     38.62
# 6896   3.6625      32.0  4.766414   0.992424      2416.0  3.050505     34.05
# 492    1.7652      52.0  3.534521   0.988864       878.0  1.955457     37.86
# ...       ...       ...       ...        ...         ...       ...       ...
# 2542   1.8529      52.0  4.880878   1.078370       758.0  2.376176     40.80
# 9253   2.4196      41.0  6.807018   1.233918       476.0  2.783626     36.95
# 12790  2.6369       5.0  5.381526   1.008032      1885.0  3.785141     38.65
# 6743   4.1136      30.0  4.145009   1.052731      1194.0  2.248588     34.12
# 2461   2.8125      29.0  6.078571   1.075000       914.0  3.264286     36.46
#
#        Longitude  median_house_value
# ...

# %%
train_data.hist(figsize=(15, 8))
# Out:
# array([[<Axes: title={'center': 'MedInc'}>,
#         <Axes: title={'center': 'HouseAge'}>,
#         <Axes: title={'center': 'AveRooms'}>],
#        [<Axes: title={'center': 'AveBedrms'}>,
#         <Axes: title={'center': 'Population'}>,
#         <Axes: title={'center': 'AveOccup'}>],
#        [<Axes: title={'center': 'Latitude'}>,
#         <Axes: title={'center': 'Longitude'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
plt.figure(figsize=(15,8))
sns.heatmap(train_data.corr(), annot=True, cmap="Blues")
# Out:
# <Axes: >

# %%
print(train_data.columns)
# Out:
# Index(['MedInc', 'HouseAge', 'AveRooms', 'AveBedrms', 'Population', 'AveOccup',
#        'Latitude', 'Longitude', 'median_house_value'],
#       dtype='object')

# %%
train_data['total_rooms'] = np.log(data['total_rooms'] + 1)
train_data['total_bedrooms'] = np.log(data['total_bedrooms'] + 1)
train_data['population'] = np.log(data['population'] + 1)
train_data['households'] = np.log(data['households'] + 1)

# %%
train_data.hist(figsize=(15,8))
# Out:
# array([[<Axes: title={'center': 'MedInc'}>,
#         <Axes: title={'center': 'HouseAge'}>,
#         <Axes: title={'center': 'AveRooms'}>],
#        [<Axes: title={'center': 'AveBedrms'}>,
#         <Axes: title={'center': 'Population'}>,
#         <Axes: title={'center': 'AveOccup'}>],
#        [<Axes: title={'center': 'Latitude'}>,
#         <Axes: title={'center': 'Longitude'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
print(train_data.columns)
# Out:
# Index(['MedInc', 'HouseAge', 'AveRooms', 'AveBedrms', 'Population', 'AveOccup',
#        'Latitude', 'Longitude', 'median_house_value'],
#       dtype='object')

# %%
if 'ocean_proximity' in train_data.columns:
    ocean_dummies = pd.get_dummies(train_data['ocean_proximity'])
    train_data = train_data.join(ocean_dummies)
    train_data = train_data.drop(['ocean_proximity'], axis=1)
else:
    print("Kolom 'ocean_proximity' tidak ditemukan.")
# Out:
# Kolom 'ocean_proximity' tidak ditemukan.

# %%
plt.figure(figsize=(15,8))
sns.heatmap(train_data.corr(), annot=True, cmap="Blues")
# Out:
# <Axes: >

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(15, 8))
sns.scatterplot(
    x="longitude",
    y="latitude",
    data=train_data,
    hue="median_house_value",
    palette="coolwarm"
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[54], line 5
#       2 import matplotlib.pyplot as plt
#       4 plt.figure(figsize=(15, 8))
# ----> 5 sns.scatterplot(
#       6     x="longitude",
#       7     y="latitude",
#       8     data=train_data,
#       9     hue="median_house_value",
#      10     palette="coolwarm"
#      11 )
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\seaborn\relational.py:615, in scatterplot(data, x, y, hue, size, style, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, legend, ax, **kwargs)
#     606 def scatterplot(
#     607     data=None, *,
#     608     x=None, y=None, hue=None, size=None, style=None,
#    (...)    612     **kwargs
#     613 ):
# --> 615     p = _ScatterPlotter(
#     616         data=data,
# ...
